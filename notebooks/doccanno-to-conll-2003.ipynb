# %%
import pandas as pd
from nltk.tokenize import TreebankWordTokenizer as twt

# %%
import jsonlines

annotated_data = []

with jsonlines.open('../data/annotated-ner.json1') as reader:
    for obj in reader:
        # Getting only the documents with annotations
        if len(obj['labels']) > 0:
            annotated_data.append(obj)

# %%
def merge_adjacent_labels(labels):
    merged_labels = []
    prev_label = None
    new_label = None
    
    for label in labels:
        if prev_label == None:
            new_label = [label[0], label[1], label[2]]
            prev_label = label
            continue
        
        if prev_label[1] + 1 == label[0] and prev_label[2] == label[2]:
            new_label[1] = label[1]
        else:
            merged_labels.append(new_label)
            new_label = [label[0], label[1], label[2]]
        prev_label = label
    return merged_labels

with jsonlines.open('../data/annotated-ner-semi-supervised-v2.json1') as reader:
    for obj in reader:
        # Getting only the documents with annotations
        if len(obj['labels']) > 0:
            obj['labels'] = merge_adjacent_labels(obj['labels'])
            annotated_data.append(obj)

# %%
annotated_data[0]
# Out:
# {'id': 1,
#  'text': 'РЕШЕНИЕ\n\n№53\n\nгр. София, 26.07.2018 год. В ИМЕТО НА НА Р О Д А \n\n\n\nВЪРХОВНИЯТ КАСАЦИОНЕН СЪД на Република България, ІІ гражданско отделение, в открито съдебно заседание на шестнадесети април две хиляди и осемнадесета година, в състав:\n \n\nПРЕДСЕДАТЕЛ: ЕМАНУЕЛА БАЛЕВСКА\n\nЧЛЕНОВЕ: СНЕЖАНКА НИКОЛОВА\n\nГЕРГАНА НИКОВА\n \nпри участието на секретаря Т. Иванова, като разгледа докладваното от съдията Николова гр. д. №53 по описа на Върховния касационен съд за 2017 год. на ІІ г. о. и за да се произнесе, взе предвид следното:\n\n\nПроизводството е по чл. 290 и сл. от ГПК. Образувано е по касационната жалба на Местно поделение Мюсюлманско настоятелство, [населено място], Велинградска община, представлявано от председателя С.',
#  'meta': {},
#  'annotation_approver': None,
#  'labels': [[0, 12, 'REF-DOC'],
#   [14, 23, 'LOC-CITY'],
#   [25, 35, 'DATE'],
#   [62, 92, 'ORG-COURT'],
#   [96, 114, 'LOC-CTRY'],
#   [172, 223, 'DATE'],
#   [392, 400, 'PER-JDG'],
#   [424, 448, 'ORG-COURT'],
#   [452, 456, 'DATE'],
#   [251, 268, 'PER-OTH'],
#   [279, 296, 'PER-OTH'],
#   [298, 312, 'PER-OTH'],
#   [540, 560, 'REF-LAW'],
#   [600, 642, 'ORG-INST'],
#   [644, 660, 'LOC-CITY'],
#   [662, 681, 'LOC-OTH'],
#   [701, 715, 'PER-OTH'],
#   [342, 352, 'PER-OTH']]}

# %%
# This will be used to determine whether token span matches annotation span
def are_intersecting(b1, b2):
    if b1[0] >= b2[0] and b1[1] <= b2[1]:
        return True
    return False

# Getting labels as list of pairs (span_x, span_y, label)
def get_labels(raw_labels):
    return [((l[0], l[1]), l[2]) for l in raw_labels]

def map_tokens_with_labels(annotated_doc):
    # Sorting labels for idempotency 
    annotated_doc['labels'].sort(key=lambda x: x[0], reverse=False)
    labels = get_labels(annotated_doc['labels'])
    current_label = 0
    
    token_spans = list(twt().span_tokenize(annotated_doc['text']))
    tokens = twt().tokenize(annotated_doc['text'])
    
    mapped_tokens = []
    was_entity = False

    for token_span in zip(tokens, token_spans):
        if current_label >= len(labels):
            mapped_tokens.append((token_span, 'O'))
            continue
            
        if are_intersecting(token_span[1], labels[current_label][0]):
            mapped_tokens.append((token_span, labels[current_label][1]))
            was_entity = True
        else:
            mapped_tokens.append((token_span, 'O'))
            if was_entity:
                was_entity = False
                current_label += 1
    return mapped_tokens

# %%
map_tokens_with_labels(annotated_data[5])
# Out:
# [(('Ако', (0, 3)), 'O'),
#  (('местното', (4, 12)), 'O'),
#  (('поделение', (13, 22)), 'O'),
#  (('на', (23, 25)), 'O'),
#  (('вероизповеданието', (26, 43)), 'O'),
#  (('е', (44, 45)), 'O'),
#  (('заварено', (46, 54)), 'O'),
#  (('юридическо', (55, 65)), 'O'),
#  (('лице', (66, 70)), 'O'),
#  (('по', (71, 73)), 'O'),
#  (('смисъла', (74, 81)), 'O'),
#  (('на', (82, 84)), 'O'),
#  (('цитираната', (85, 95)), 'O'),
#  (('норма', (96, 101)), 'O'),
#  ((',', (101, 102)), 'O'),
#  (('то', (103, 105)), 'O'),
#  (('не', (106, 108)), 'O'),
#  (('изгубва', (109, 116)), 'O'),
#  (('своята', (117, 123)), 'O'),
#  (('правосубектност', (124, 139)), 'O'),
#  (('по', (140, 142)), 'O'),
#  (('силата', (143, 149)), 'O'),
#  (('ЗВ', (150, 152)), 'O'),
#  ((',', (152, 153)), 'O'),
#  (('дори', (154, 158)), 'O'),
#  (('при', (159, 162)), 'O'),
#  (('неизвършване', (163, 175)), 'O'),
#  (('на', (176, 178)), 'O'),
#  (('служебното', (179, 189)), 'O'),
#  (('вписване.', (190, 199)), 'O'),
#  (('Предвиденият', (200, 212)), 'O'),
#  (('в', (213, 214)), 'O'),
#  (('новия', (215, 220)), 'O'),
#  (('закон', (221, 226)), 'O'),
#  (('режим', (227, 232)), 'O'),
#  (('на', (233, 235)), 'O'),
#  (('регистрация', (236, 247)), 'O'),
#  (('на', (248, 250)), 'O'),
#  (('вероизповеданията', (251, 268)), 'O'),
#  (('установява', (269, 279)), 'O'),
#  (('запазване', (280, 289)), 'O'),
#  (('статута', (290, 297)), 'O'),
#  (('на', (298, 300)), 'O'),
#  (('съществуващите', (301, 315)), 'O'),
#  (('към', (316, 319)), 'O'),
#  (('момента', (320, 327)), 'O'),
#  (('на', (328, 330)), 'O'),
#  (('влизането', (331, 340)), 'O'),
#  (('в', (341, 342)), 'O'),
#  (('сила', (343, 347)), 'O'),
#  (('вероизповедания', (348, 363)), 'O'),
#  (('и', (364, 365)), 'O'),
#  (('техните', (366, 373)), 'O'),
#  (('поделения', (374, 383)), 'O'),
#  ((',', (383, 384)), 'O'),
#  (('в', (385, 386)), 'O'),
#  (('който', (387, 392)), 'O'),
#  (('смисъл', (393, 399)), 'O'),
#  (('е', (400, 401)), 'O'),
#  (('задължителната', (402, 416)), 'O'),
#  (('съдебна', (417, 424)), 'O'),
#  (('практика', (425, 433)), 'O'),
#  (('на', (434, 436)), 'O'),
#  (('ВКС', (437, 440)), 'ORG-COURT'),
#  (('–', (441, 442)), 'O'),
#  (('решение', (443, 450)), 'REF-DOC'),
#  (('№53', (451, 454)), 'REF-DOC'),
#  (('от', (455, 457)), 'O'),
#  (('21.07.2010', (458, 468)), 'DATE'),
#  (('г.', (469, 471)), 'O'),
#  (('по', (472, 474)), 'O'),
#  (('гр.', (475, 478)), 'REF-DOC'),
#  (('д.', (479, 481)), 'REF-DOC'),
#  (('№53/2009', (482, 490)), 'REF-DOC'),
#  (('г.', (491, 493)), 'O'),
#  (('на', (494, 496)), 'O'),
#  (('ВКС', (497, 500)), 'ORG-COURT'),
#  ((',', (500, 501)), 'O'),
#  (('II', (502, 504)), 'O'),
#  (('г.', (505, 507)), 'O'),
#  (('о.', (508, 510)), 'O'),
#  (('Мюсюлманските', (511, 524)), 'O'),
#  (('изповедания', (525, 536)), 'O'),
#  (('нямат', (537, 542)), 'O'),
#  (('регистрирана', (543, 555)), 'O'),
#  (('членска', (556, 563)), 'O'),
#  (('маса', (564, 568)), 'O'),
#  (('–', (569, 570)), 'O'),
#  (('персоналният', (571, 583)), 'O'),
#  (('субстрат', (584, 592)), 'O'),
#  (('на', (593, 595)), 'O'),
#  (('религиозната', (596, 608)), 'O'),
#  (('общност', (609, 616)), 'O'),
#  (('обхваща', (617, 624)), 'O'),
#  (('лица', (625, 629)), 'O'),
#  ((',', (629, 630)), 'O'),
#  (('изповядващи', (631, 642)), 'O'),
#  (('исляма', (643, 649)), 'O'),
#  (('и', (650, 651)), 'O'),
#  (('подчиняващи', (652, 663)), 'O'),
#  (('се', (664, 666)), 'O'),
#  (('на', (667, 669)), 'O'),
#  (('изискванията', (670, 682)), 'O'),
#  (('на', (683, 685)), 'O'),
#  (('тази', (686, 690)), 'O'),
#  (('религия', (691, 698)), 'O'),
#  ((',', (698, 699)), 'O'),
#  (('които', (700, 705)), 'O'),
#  (('съобразно', (706, 715)), 'O'),
#  (('местоживеенето', (716, 730)), 'O'),
#  (('си', (731, 733)), 'O'),
#  (('принадлежат', (734, 745)), 'O'),
#  (('към', (746, 749)), 'O'),
#  (('една', (750, 754)), 'O'),
#  (('или', (755, 758)), 'O'),
#  (('друга', (759, 764)), 'O'),
#  (('местна', (765, 771)), 'O'),
#  (('религиозна', (772, 782)), 'O'),
#  (('общност', (783, 790)), 'O'),
#  (('–', (791, 792)), 'O'),
#  (('специфика', (793, 802)), 'O'),
#  (('на', (803, 805)), 'O'),
#  (('персоналния', (806, 817)), 'O'),
#  (('субстрат', (818, 826)), 'O'),
#  (('на', (827, 829)), 'O'),
#  (('изповеданието', (830, 843)), 'O'),
#  ((',', (843, 844)), 'O'),
#  (('върху', (845, 850)), 'O'),
#  (('чиято', (851, 856)), 'O'),
#  (('воля', (857, 861)), 'O'),
#  (('почива', (862, 868)), 'O'),
#  (('институционализирането', (869, 891)), 'O'),
#  (('на', (892, 894)), 'O'),
#  (('същото.', (895, 902)), 'O'),
#  (('Преминаването', (903, 916)), 'O'),
#  (('на', (917, 919)), 'O'),
#  (('членската', (920, 929)), 'O'),
#  (('маса', (930, 934)), 'O'),
#  (('на', (935, 937)), 'O'),
#  (('местната', (938, 946)), 'O'),
#  (('структура', (947, 956)), 'O'),
#  (('от', (957, 959)), 'O'),
#  (('едно', (960, 964)), 'O'),
#  (('вероизповедание', (965, 980)), 'O'),
#  (('в', (981, 982)), 'O'),
#  (('друго', (983, 988)), 'O'),
#  (('не', (989, 991)), 'O'),
#  (('е', (992, 993)), 'O'),
#  (('индиция', (994, 1001)), 'O'),
#  (('за', (1002, 1004)), 'O'),
#  (('идентичност', (1005, 1016)), 'O'),
#  (('на', (1017, 1019)), 'O'),
#  (('местните', (1020, 1028)), 'O'),
#  (('структури', (1029, 1038)), 'O'),
#  ((',', (1038, 1039)), 'O'),
#  (('нито', (1040, 1044)), 'O'),
#  (('води', (1045, 1049)), 'O'),
#  (('до', (1050, 1052)), 'O'),
#  (('правоприемство', (1053, 1067)), 'O'),
#  (('между', (1068, 1073)), 'O'),
#  (('тях', (1074, 1077)), 'O'),
#  ((',', (1077, 1078)), 'O'),
#  (('съответно', (1079, 1088)), 'O'),
#  (('до', (1089, 1091)), 'O'),
#  (('прехвърляне', (1092, 1103)), 'O'),
#  (('на', (1104, 1106)), 'O'),
#  (('права', (1107, 1112)), 'O'),
#  (('и', (1113, 1114)), 'O'),
#  (('задължения.', (1115, 1126)), 'O'),
#  (('Същото', (1127, 1133)), 'O'),
#  (('е', (1134, 1135)), 'O'),
#  (('възможно', (1136, 1144)), 'O'),
#  (('само', (1145, 1149)), 'O'),
#  (('с', (1150, 1151)), 'O'),
#  (('решение', (1152, 1159)), 'O'),
#  (('на', (1160, 1162)), 'O'),
#  (('органа', (1163, 1169)), 'O'),
#  ((',', (1169, 1170)), 'O'),
#  (('учредил', (1171, 1178)), 'O'),
#  (('съответната', (1179, 1190)), 'O'),
#  (('местна', (1191, 1197)), 'O'),
#  (('структура.', (1198, 1208)), 'O'),
#  (('Самото', (1209, 1215)), 'O'),
#  (('преминаване', (1216, 1227)), 'O'),
#  (('на', (1228, 1230)), 'O'),
#  (('членската', (1231, 1240)), 'O'),
#  (('маса', (1241, 1245)), 'O'),
#  (('е', (1246, 1247)), 'O'),
#  (('предпоставка', (1248, 1260)), 'O'),
#  (('за', (1261, 1263)), 'O'),
#  (('образуване', (1264, 1274)), 'O'),
#  (('на', (1275, 1277)), 'O'),
#  (('ново', (1278, 1282)), 'O'),
#  (('юридическо', (1283, 1293)), 'O'),
#  (('лице', (1294, 1298)), 'O'),
#  ((',', (1298, 1299)), 'O'),
#  (('самостоятелен', (1300, 1313)), 'O'),
#  (('правен', (1314, 1320)), 'O'),
#  (('субект', (1321, 1327)), 'O'),
#  ((',', (1327, 1328)), 'O'),
#  (('носител', (1329, 1336)), 'O'),
#  (('на', (1337, 1339)), 'O'),
#  (('свои', (1340, 1344)), 'O'),
#  (('материални', (1345, 1355)), 'O'),
#  (('права', (1356, 1361)), 'O'),
#  (('и', (1362, 1363)), 'O'),
#  (('задължения.', (1364, 1375)), 'O'),
#  (('При', (1376, 1379)), 'O'),
#  (('тези', (1380, 1384)), 'O'),
#  (('съображения', (1385, 1396)), 'O'),
#  (('настоящият', (1397, 1407)), 'O'),
#  (('състав', (1408, 1414)), 'O'),
#  ((',', (1414, 1415)), 'O'),
#  (('произнасяйки', (1416, 1428)), 'O'),
#  (('се', (1429, 1431)), 'O'),
#  (('по', (1432, 1434)), 'O'),
#  (('същество', (1435, 1443)), 'O'),
#  (('на', (1444, 1446)), 'O'),
#  (('касационната', (1447, 1459)), 'O'),
#  (('жалба', (1460, 1465)), 'O'),
#  ((',', (1465, 1466)), 'O'),
#  (('приема', (1467, 1473)), 'O'),
#  (('следното', (1474, 1482)), 'O'),
#  ((':', (1482, 1483)), 'O'),
#  (('За', (1486, 1488)), 'O'),
#  (('да', (1489, 1491)), 'O'),
#  (('потвърди', (1492, 1500)), 'O'),
#  (('първоинстанционното', (1501, 1520)), 'O'),
#  (('решение', (1521, 1528)), 'O'),
#  ((',', (1528, 1529)), 'O'),
#  (('с', (1530, 1531)), 'O'),
#  (('което', (1532, 1537)), 'O'),
#  (('е', (1538, 1539)), 'O'),
#  (('отхвърлен', (1540, 1549)), 'O'),
#  (('искът', (1550, 1555)), 'O'),
#  (('по', (1556, 1558)), 'O'),
#  (('чл.', (1559, 1562)), 'REF-LAW'),
#  (('124', (1563, 1566)), 'REF-LAW'),
#  ((',', (1566, 1567)), 'REF-LAW'),
#  (('ал.', (1568, 1571)), 'REF-LAW'),
#  (('1', (1572, 1573)), 'REF-LAW'),
#  (('ГПК', (1574, 1577)), 'REF-LAW'),
#  (('и', (1578, 1579)), 'O'),
#  (('искът', (1580, 1585)), 'O'),
#  (('за', (1586, 1588)), 'O'),
#  (('отмяна', (1589, 1595)), 'O'),
#  (('на', (1596, 1598)), 'O'),
#  (('нотариален', (1599, 1609)), 'REF-DOC'),
#  (('акт', (1610, 1613)), 'REF-DOC'),
#  (('№53/2009', (1614, 1622)), 'REF-DOC'),
#  (('г.', (1623, 1625)), 'O'),
#  ((',', (1625, 1626)), 'O'),
#  (('с', (1627, 1628)), 'O'),
#  (('който', (1629, 1634)), 'O'),
#  (('се', (1635, 1637)), 'O'),
#  (('признава', (1638, 1646)), 'O'),
#  (('правото', (1647, 1654)), 'O'),
#  (('на', (1655, 1657)), 'O'),
#  (('собственост', (1658, 1669)), 'O'),
#  (('на', (1670, 1672)), 'O'),
#  (('ответника', (1673, 1682)), 'O'),
#  (('върху', (1683, 1688)), 'O'),
#  (('процесния', (1689, 1698)), 'O'),
#  (('имот', (1699, 1703)), 'O'),
#  ((',', (1703, 1704)), 'O'),
#  (('въззивната', (1705, 1715)), 'O'),
#  (('инстанция', (1716, 1725)), 'O'),
#  (('е', (1726, 1727)), 'O'),
#  (('приела', (1728, 1734)), 'O'),
#  ((',', (1734, 1735)), 'O'),
#  (('че', (1736, 1738)), 'O'),
#  (('правоприемство', (1739, 1753)), 'O'),
#  (('между', (1754, 1759)), 'O'),
#  (('ищеца', (1760, 1765)), 'O'),
#  (('Местно', (1766, 1772)), 'O'),
#  (('поделение', (1773, 1782)), 'O'),
#  (('Мюсюлманско', (1783, 1794)), 'O'),
#  (('настоятелство', (1795, 1808)), 'O'),
#  ((',', (1808, 1809)), 'O'),
#  (('[', (1810, 1811)), 'O'),
#  (('населено', (1811, 1819)), 'O'),
#  (('място', (1820, 1825)), 'O'),
#  ((']', (1825, 1826)), 'O'),
#  (('и', (1827, 1828)), 'O'),
#  (('Мюсюлманско', (1829, 1840)), 'O'),
#  (('настоятелство', (1841, 1854)), 'O'),
#  ((',', (1854, 1855)), 'O'),
#  (('[', (1856, 1857)), 'O'),
#  (('населено', (1857, 1865)), 'O'),
#  (('място', (1866, 1871)), 'O'),
#  ((']', (1871, 1872)), 'O'),
#  ((',', (1872, 1873)), 'O'),
#  (('с', (1874, 1875)), 'O'),
#  (('[', (1875, 1876)), 'O'),
#  (('ЕИК', (1876, 1879)), 'O'),
#  ((']', (1879, 1880)), 'O'),
#  (('/местното', (1881, 1890)), 'O'),
#  (('поделение', (1891, 1900)), 'O'),
#  (('на', (1901, 1903)), 'O'),
#  (('ответника', (1904, 1913)), 'O'),
#  (('към', (1914, 1917)), 'O'),
#  (('влизане', (1918, 1925)), 'O'),
#  (('в', (1926, 1927)), 'O'),
#  (('сила', (1928, 1932)), 'O'),
#  (('на', (1933, 1935)), 'O'),
#  (('ЗВ', (1936, 1938)), 'REF-DOC'),
#  ((',', (1938, 1939)), 'REF-DOC'),
#  (('обн.', (1940, 1944)), 'REF-DOC'),
#  (('ДВ', (1945, 1947)), 'REF-DOC'),
#  (('бр.', (1948, 1951)), 'REF-DOC'),
#  (('120', (1952, 1955)), 'REF-DOC'),
#  (('от', (1956, 1958)), 'REF-DOC'),
#  (('29.12.2002', (1959, 1969)), 'REF-DOC'),
#  (('г./', (1970, 1973)), 'O'),
#  ((',', (1973, 1974)), 'O'),
#  (('съответно', (1975, 1984)), 'O'),
#  (('правоприемство', (1985, 1999)), 'O'),
#  (('на', (2000, 2002)), 'O'),
#  (('правото', (2003, 2010)), 'O'),
#  (('на', (2011, 2013)), 'O'),
#  (('собственост', (2014, 2025)), 'O'),
#  (('от', (2026, 2028)), 'O'),
#  (('титуляра', (2029, 2037)), 'O'),
#  (('му', (2038, 2040)), 'O'),
#  (('към', (2041, 2044)), 'O'),
#  (('1998', (2045, 2049)), 'DATE'),
#  (('г.', (2050, 2052)), 'O'),
#  (('„', (2053, 2054)), 'O'),
#  (('Д.', (2054, 2056)), 'O'),
#  (('настоятелство', (2057, 2070)), 'O'),
#  (('”', (2070, 2071)), 'O'),
#  (('-', (2072, 2073)), 'O'),
#  (('[', (2074, 2075)), 'O'),
#  (('населено', (2075, 2083)), 'O'),
#  (('място', (2084, 2089)), 'O'),
#  ((']', (2089, 2090)), 'O'),
#  ((',', (2090, 2091)), 'O'),
#  (('не', (2092, 2094)), 'O'),
#  (('е', (2095, 2096)), 'O'),
#  (('доказано.', (2097, 2106)), 'O'),
#  (('Изложени', (2107, 2115)), 'O'),
#  (('са', (2116, 2118)), 'O'),
#  (('съображения', (2119, 2130)), 'O'),
#  ((',', (2130, 2131)), 'O'),
#  (('че', (2132, 2134)), 'O'),
#  (('от', (2135, 2137)), 'O'),
#  (('вписването', (2138, 2148)), 'O'),
#  (('на', (2149, 2151)), 'O'),
#  (('ищцовото', (2152, 2160)), 'O'),
#  (('Местно', (2161, 2167)), 'O'),
#  (('поделение', (2168, 2177)), 'O'),
#  (('Мюсюлманско', (2178, 2189)), 'O'),
#  (('настоятелство', (2190, 2203)), 'O'),
#  (('като', (2204, 2208)), 'O'),
#  (('юридическо', (2209, 2219)), 'O'),
#  (('лице', (2220, 2224)), 'O'),
#  (('през', (2225, 2229)), 'O'),
#  (('2015', (2230, 2234)), 'DATE'),
#  (('г.', (2235, 2237)), 'O'),
#  (('/ф.', (2238, 2241)), 'O'),
#  (('д.', (2242, 2244)), 'REF-DOC'),
#  (('№53', (2245, 2248)), 'REF-DOC'),
#  (('на', (2249, 2251)), 'O'),
#  (('Пазарджишкия', (2252, 2264)), 'ORG-COURT'),
#  (('окръжен', (2265, 2272)), 'ORG-COURT'),
#  (('съд/', (2273, 2277)), 'O'),
#  (('до', (2278, 2280)), 'O'),
#  (('края', (2281, 2285)), 'DATE'),
#  (('на', (2286, 2288)), 'DATE'),
#  (('2015', (2289, 2293)), 'DATE'),
#  (('г.', (2294, 2296)), 'O'),
#  (('са', (2297, 2299)), 'O'),
#  (('съществували', (2300, 2312)), 'O'),
#  (('и', (2313, 2314)), 'O'),
#  (('двете', (2315, 2320)), 'O'),
#  (('настоятелства', (2321, 2334)), 'O'),
#  ((',', (2334, 2335)), 'O'),
#  (('като', (2336, 2340)), 'O'),
#  (('това', (2341, 2345)), 'O'),
#  ((',', (2345, 2346)), 'O'),
#  (('съществувало', (2347, 2359)), 'O'),
#  (('от', (2360, 2362)), 'O'),
#  (('1997', (2363, 2367)), 'DATE'),
#  (('г.', (2368, 2370)), 'O'),
#  (('-', (2371, 2372)), 'O'),
#  (('Мюсюлманско', (2373, 2384)), 'O'),
#  (('настоятелство', (2385, 2398)), 'O'),
#  ((',', (2398, 2399)), 'O'),
#  (('[', (2400, 2401)), 'O'),
#  (('населено', (2401, 2409)), 'O'),
#  (('място', (2410, 2415)), 'O'),
#  ((']', (2415, 2416)), 'O'),
#  ((',', (2416, 2417)), 'O'),
#  (('с', (2418, 2419)), 'O'),
#  (('ЕИК', (2420, 2423)), 'O'),
#  (('[', (2423, 2424)), 'O'),
#  (('ЕИК', (2424, 2427)), 'O'),
#  ((']', (2427, 2428)), 'O'),
#  ((',', (2428, 2429)), 'O'),
#  (('е', (2430, 2431)), 'O'),
#  (('прекратено', (2432, 2442)), 'O'),
#  (('по', (2443, 2445)), 'O'),
#  (('решение', (2446, 2453)), 'O'),
#  (('на', (2454, 2456)), 'O'),
#  (('Мюсюлманското', (2457, 2470)), 'O'),
#  (('изповедание', (2471, 2482)), 'O'),
#  ((',', (2482, 2483)), 'O'),
#  (('съгласно', (2484, 2492)), 'O'),
#  (('устава', (2493, 2499)), 'O'),
#  (('му', (2500, 2502)), 'O'),
#  ((',', (2502, 2503)), 'O'),
#  (('видно', (2504, 2509)), 'O'),
#  (('от', (2510, 2512)), 'O'),
#  (('представено', (2513, 2524)), 'O'),
#  (('удостоверение', (2525, 2538)), 'O'),
#  (('от', (2539, 2541)), 'O'),
#  (('АВп', (2542, 2545)), 'O'),
#  ((',', (2545, 2546)), 'O'),
#  (('т.', (2547, 2549)), 'O'),
#  (('е', (2550, 2551)), 'O'),
#  (('.', (2551, 2552)), 'O')]

# %%
df = pd.DataFrame([], columns=['token', 'span', 'sentence', 'tag'])

for i, doc in enumerate(annotated_data):
    mapped_tokens = map_tokens_with_labels(doc)
    for mapped_token in mapped_tokens: 
        df = df.append({
            'token': mapped_token[0][0], 
            'span': mapped_token[0][1], 
            'sentence': i, 
            'tag': mapped_token[1]
        }, ignore_index=True)

# %%
df
# Out:
#           token        span sentence       tag
# 0       РЕШЕНИЕ      (0, 7)        0   REF-DOC
# 1           №53     (9, 12)        0   REF-DOC
# 2           гр.    (14, 17)        0         O
# 3         София    (18, 23)        0  LOC-CITY
# 4             ,    (23, 24)        0         O
# ...         ...         ...      ...       ...
# 74158        на  (576, 578)      552         O
# 74159  доводите  (579, 587)      552         O
# 74160        на  (588, 590)      552         O
# 74161  защитата  (591, 599)      552         O
# 74162         .  (600, 601)      552         O
#
# [74163 rows x 4 columns]

# %%
words = list(set(df["token"].values))
len(words)
# Out:
# 8592

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 0
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t) for w, t in zip(s["token"].values.tolist(), s["tag"].values.tolist())]
        self.grouped = self.data.groupby("sentence").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped[self.n_sent]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(df)
print(getter.get_next())
# Out:
# [('РЕШЕНИЕ', 'REF-DOC'), ('№53', 'REF-DOC'), ('гр.', 'O'), ('София', 'LOC-CITY'), (',', 'O'), ('26.07.2018', 'DATE'), ('год.', 'O'), ('В', 'O'), ('ИМЕТО', 'O'), ('НА', 'O'), ('НА', 'O'), ('Р', 'O'), ('О', 'O'), ('Д', 'O'), ('А', 'O'), ('ВЪРХОВНИЯТ', 'ORG-COURT'), ('КАСАЦИОНЕН', 'ORG-COURT'), ('СЪД', 'ORG-COURT'), ('на', 'O'), ('Република', 'LOC-CTRY'), ('България', 'LOC-CTRY'), (',', 'O'), ('ІІ', 'O'), ('гражданско', 'O'), ('отделение', 'O'), (',', 'O'), ('в', 'O'), ('открито', 'O'), ('съдебно', 'O'), ('заседание', 'O'), ('на', 'O'), ('шестнадесети', 'DATE'), ('април', 'DATE'), ('две', 'DATE'), ('хиляди', 'DATE'), ('и', 'DATE'), ('осемнадесета', 'DATE'), ('година', 'DATE'), (',', 'O'), ('в', 'O'), ('състав', 'O'), (':', 'O'), ('ПРЕДСЕДАТЕЛ', 'O'), (':', 'O'), ('ЕМАНУЕЛА', 'PER-OTH'), ('БАЛЕВСКА', 'PER-OTH'), ('ЧЛЕНОВЕ', 'O'), (':', 'O'), ('СНЕЖАНКА', 'PER-OTH'), ('НИКОЛОВА', 'PER-OTH'), ('ГЕРГАНА', 'O'), ('НИКОВА', 'PER-OTH'), ('при', 'O'), ('участието', 'O'), ('на', 'O'), ('секретаря', 'O'), ('Т.', 'PER-OTH'), ('Иванова', 'PER-OTH'), (',', 'O'), ('като', 'O'), ('разгледа', 'O'), ('докладваното', 'O'), ('от', 'O'), ('съдията', 'O'), ('Николова', 'PER-JDG'), ('гр.', 'O'), ('д.', 'O'), ('№53', 'O'), ('по', 'O'), ('описа', 'O'), ('на', 'O'), ('Върховния', 'ORG-COURT'), ('касационен', 'ORG-COURT'), ('съд', 'ORG-COURT'), ('за', 'O'), ('2017', 'DATE'), ('год.', 'O'), ('на', 'O'), ('ІІ', 'O'), ('г.', 'O'), ('о.', 'O'), ('и', 'O'), ('за', 'O'), ('да', 'O'), ('се', 'O'), ('произнесе', 'O'), (',', 'O'), ('взе', 'O'), ('предвид', 'O'), ('следното', 'O'), (':', 'O'), ('Производството', 'O'), ('е', 'O'), ('по', 'O'), ('чл.', 'REF-LAW'), ('290', 'REF-LAW'), ('и', 'REF-LAW'), ('сл.', 'REF-LAW'), ('от', 'REF-LAW'), ('ГПК.', 'O'), ('Образувано', 'O'), ('е', 'O'), ('по', 'O'), ('касационната', 'O'), ('жалба', 'O'), ('на', 'O'), ('Местно', 'ORG-INST'), ('поделение', 'ORG-INST'), ('Мюсюлманско', 'ORG-INST'), ('настоятелство', 'ORG-INST'), (',', 'O'), ('[', 'LOC-CITY'), ('населено', 'LOC-CITY'), ('място', 'LOC-CITY'), (']', 'LOC-CITY'), (',', 'O'), ('Велинградска', 'LOC-OTH'), ('община', 'LOC-OTH'), (',', 'O'), ('представлявано', 'O'), ('от', 'O'), ('председателя', 'PER-OTH'), ('С', 'PER-OTH'), ('.', 'O')]

# %%
import re

def matchesRegEx(regex, word):
    res = re.match(regex, word)
    if res:
        return True
    return False

def gazeteerMoney(word):
    moneyDictionary = ['лв', 'евро', 'долара', 'лева', '$', 'щ. д.', 'щ.д.']
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerDate(word):
    moneyDictionary = ['месец', 'януари', 'февруари', 'март', 'април', 'май', 'юни', 'юли', 'август', 'септември', 'октомври', 'ноември', 'декември', 'година', 'год.', 'г.']
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerCourt(word):
    dictionary = ["PC", "ОС", "СГС", "АДМС", "АС", "ВКС", "ВАС", 'СЪД', 'ЕСПЧ']
    for w in dictionary:
        res = re.match(w, word.upper())
        if res:
            return True
    return False
    
def gazeteerJudge(word):
    moneyDictionary = ['съд.', 'съдия']
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerInstitution(word):
    moneyDictionary = ['БНТ', 'съдия', 'ЕС', 'КЗК', 'МВР', 'НАП', ]
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerDocRef(word):
    moneyDictionary = ['бел', 'бр', 'ДВ', "к.д.", ]
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerJudge(word):
    moneyDictionary = ['съд.', 'съдия']
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerCountry(word):
    moneyDictionary = ['РБ', 'ГДР', 'КРБ', 'България', 'Сърбия', 'Румъния', 'САЩ']
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def gazeteerLaw(word):
    moneyDictionary = ['чл', 'ал', 'алинея', 'т', "НК", "НПК", "ГПК", "АПК", "СК", "ЗАНН", "ЗГС", "ЗЗД", "ЗЗК", "ЗЗП", "ЗИДАПК", "ЗИД", "ЗНА", "ЗРТ", "ЗХр", "ЗСВ"]
    for w in moneyDictionary:
        res = re.match(w, word)
        if res:
            return True
    return False

def word2features(sent, i):
    word = sent[i][0]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[:-2]': word[:-2],
        'word[:-1]': word[:-1],
        'word[-1:]': word[-1:],
        'word[-2:]': word[-2:],
        'ispunctuation': matchesRegEx("[,\.;:\?!-+\"]", word),
        'containsDash': matchesRegEx(".*-.*", word),
        'containsDot': matchesRegEx(".*\..*", word),
        'containsDigit': matchesRegEx(".*[0-9].*", word),
        'lonleyInitial': matchesRegEx("[А-Я]\.", word),
        'singleChar': matchesRegEx("[А-Яа-я]", word),
        'singleDigit': matchesRegEx("[0-9]", word),
        'hasQuote': matchesRegEx("[\"']", word),
        'endsWithDot': matchesRegEx(".*\.", word),
        'fourDigitsYear': matchesRegEx("\d{4}", word),
        'gazeteerMoney': gazeteerMoney(word),
        'gazeteerJudge': gazeteerJudge(word),
        'gazeteerCountry': gazeteerCountry(word),
        'gazeteerInstitution': gazeteerInstitution(word),
        'gazeteerDocRef': gazeteerDocRef(word),
        'gazeteerDate': gazeteerDate(word),
        'gazeteerCourt': gazeteerCourt(word),
        'gazeteerLaw': gazeteerLaw(word),
        'word.isupper()': word.isupper(),
        'word.islower()': word.islower(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
    }
    if i > 0:
        word1 = sent[i-1][0]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:ispunctuation': matchesRegEx("[,\.;:\?!-+\"]", word1),
            '-1:containsDash': matchesRegEx(".*-.*", word1),
            '-1:containsDot': matchesRegEx(".*\..*", word1),
            '-1:containsDigit': matchesRegEx(".*[0-9].*", word1),
            '-1:singleDigit': matchesRegEx("[0-9]", word1),
            '-1:endsWithDot': matchesRegEx(".*\.", word1),
            '-1:gazeteerMoney': gazeteerMoney(word),
            '-1:gazeteerJudge': gazeteerJudge(word),
            '-1:gazeteerCountry': gazeteerCountry(word),
            '-1:gazeteerInstitution': gazeteerInstitution(word),
            '-1:gazeteerDocRef': gazeteerDocRef(word),
            '-1:lonleyInitial': matchesRegEx("[А-Я]\.", word1),
            '-1:singleChar': matchesRegEx("[А-Яа-я]", word1),
            '-1:fourDigitsYear': matchesRegEx("\d{4}", word1),
            '-1:gazeteerMoney': gazeteerMoney(word1),
            '-1:gazeteerDate': gazeteerDate(word1),
            '-1:gazeteerCourt': gazeteerCourt(word1),
            '-1:gazeteerLaw': gazeteerLaw(word1),
            '-1:hasQuote': matchesRegEx("[\"']", word1),
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:ispunctuation': matchesRegEx("[,\.;:\?!-+\"]", word1),
            '+1:containsDash': matchesRegEx(".*-.*", word1),
            '+1:containsDot': matchesRegEx(".*\..*", word1),
            '+1:containsDigit': matchesRegEx(".*[0-9].*", word1),
            '+1:singleDigit': matchesRegEx("[0-9]", word1),
            '+1:endsWithDot': matchesRegEx(".*\.", word1),
            '+1:lonleyInitial': matchesRegEx("[А-Я]\.", word1),
            '+1:singleChar': matchesRegEx("[А-Яа-я]", word1),
            '+1:fourDigitsYear': matchesRegEx("\d{4}", word1),
            '+1:gazeteerMoney': gazeteerMoney(word),
            '+1:gazeteerJudge': gazeteerJudge(word),
            '+1:gazeteerCountry': gazeteerCountry(word),
            '+1:gazeteerInstitution': gazeteerInstitution(word),
            '+1:gazeteerDocRef': gazeteerDocRef(word),
            '+1:gazeteerMoney': gazeteerMoney(word1),
            '+1:gazeteerDate': gazeteerDate(word1),
            '+1:gazeteerCourt': gazeteerCourt(word1),
            '+1:gazeteerLaw': gazeteerLaw(word1),
            '+1:hasQuote': matchesRegEx("[\"']", word1)
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, label in sent]

# %%
sent = getter.get_next()
sent2features(sent)
# Out:
# [{'bias': 1.0,
#   'word.lower()': 'и.',
#   'word[:-2]': '',
#   'word[:-1]': 'И',
#   'word[-1:]': '.',
#   'word[-2:]': 'И.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': True,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': True,
#   'word.islower()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'BOS': True,
#   '+1:word.lower()': 'с.',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': True,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': True,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'с.',
#   'word[:-2]': '',
#   'word[:-1]': 'С',
#   'word[-1:]': '.',
#   'word[-2:]': 'С.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': True,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': True,
#   'word.islower()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'и.',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': True,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': True,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': True,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': ',',
#   'word[:-2]': '',
#   'word[:-1]': '',
#   'word[-1:]': ',',
#   'word[-2:]': ',',
#   'ispunctuation': True,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'с.',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': True,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': True,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'чрез',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'чрез',
#   'word[:-2]': 'чр',
#   'word[:-1]': 'чре',
#   'word[-1:]': 'з',
#   'word[-2:]': 'ез',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': True,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': False,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'пълномощника',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'пълномощника',
#   'word[:-2]': 'пълномощни',
#   'word[:-1]': 'пълномощник',
#   'word[-1:]': 'а',
#   'word[-2:]': 'ка',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'чрез',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'му',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'му',
#   'word[:-2]': '',
#   'word[:-1]': 'м',
#   'word[-1:]': 'у',
#   'word[-2:]': 'му',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'пълномощника',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'адвокат',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'адвокат',
#   'word[:-2]': 'адвок',
#   'word[:-1]': 'адвока',
#   'word[-1:]': 'т',
#   'word[-2:]': 'ат',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'му',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'д.',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': True,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': True,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'д.',
#   'word[:-2]': '',
#   'word[:-1]': 'Д',
#   'word[-1:]': '.',
#   'word[-2:]': 'Д.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': True,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': True,
#   'word.islower()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'адвокат',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'н.',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': True,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': True,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'н.',
#   'word[:-2]': '',
#   'word[:-1]': 'Н',
#   'word[-1:]': '.',
#   'word[-2:]': 'Н.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': True,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': True,
#   'word.islower()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'д.',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': True,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': True,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': True,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': ',',
#   'word[:-2]': '',
#   'word[:-1]': '',
#   'word[-1:]': ',',
#   'word[-2:]': ',',
#   'ispunctuation': True,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'н.',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': True,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': True,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'срещу',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'срещу',
#   'word[:-2]': 'сре',
#   'word[:-1]': 'срещ',
#   'word[-1:]': 'у',
#   'word[-2:]': 'щу',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': True,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': False,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'въззивно',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'въззивно',
#   'word[:-2]': 'въззив',
#   'word[:-1]': 'въззивн',
#   'word[-1:]': 'о',
#   'word[-2:]': 'но',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'срещу',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'решение',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'решение',
#   'word[:-2]': 'решен',
#   'word[:-1]': 'решени',
#   'word[-1:]': 'е',
#   'word[-2:]': 'ие',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'въззивно',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': '№53',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': True,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': '№53',
#   'word[:-2]': '№',
#   'word[:-1]': '№5',
#   'word[-1:]': '3',
#   'word[-2:]': '53',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': True,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'решение',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'от',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'от',
#   'word[:-2]': '',
#   'word[:-1]': 'о',
#   'word[-1:]': 'т',
#   'word[-2:]': 'от',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '№53',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': True,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': False,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': '16.12.2016',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': True,
#   '+1:singleDigit': True,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': '16.12.2016',
#   'word[:-2]': '16.12.20',
#   'word[:-1]': '16.12.201',
#   'word[-1:]': '6',
#   'word[-2:]': '16',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': True,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': True,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'от',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'г.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': True,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'г.',
#   'word[:-2]': '',
#   'word[:-1]': 'г',
#   'word[-1:]': '.',
#   'word[-2:]': 'г.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': True,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '16.12.2016',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': True,
#   '-1:singleDigit': True,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': False,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'по',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'по',
#   'word[:-2]': '',
#   'word[:-1]': 'п',
#   'word[-1:]': 'о',
#   'word[-2:]': 'по',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'г.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': True,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'в.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'в.',
#   'word[:-2]': '',
#   'word[:-1]': 'в',
#   'word[-1:]': '.',
#   'word[-2:]': 'в.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'по',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'гр.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': True,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'гр.',
#   'word[:-2]': 'г',
#   'word[:-1]': 'гр',
#   'word[-1:]': '.',
#   'word[-2:]': 'р.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': True,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'в.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'д.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'д.',
#   'word[:-2]': '',
#   'word[:-1]': 'д',
#   'word[-1:]': '.',
#   'word[-2:]': 'д.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'гр.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': True,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': '№53/2016',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': True,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': '№53/2016',
#   'word[:-2]': '№53/20',
#   'word[:-1]': '№53/201',
#   'word[-1:]': '6',
#   'word[-2:]': '16',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': True,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'д.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'г.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': True,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'г.',
#   'word[:-2]': '',
#   'word[:-1]': 'г',
#   'word[-1:]': '.',
#   'word[-2:]': 'г.',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': True,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '№53/2016',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': True,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': False,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'на',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'на',
#   'word[:-2]': '',
#   'word[:-1]': 'н',
#   'word[-1:]': 'а',
#   'word[-2:]': 'на',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'г.',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': True,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': True,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': True,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'окръжен',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'окръжен',
#   'word[:-2]': 'Окръж',
#   'word[:-1]': 'Окръже',
#   'word[-1:]': 'н',
#   'word[-2:]': 'ен',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'на',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'съд',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': True,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'съд',
#   'word[:-2]': 'с',
#   'word[:-1]': 'съ',
#   'word[-1:]': 'д',
#   'word[-2:]': 'ъд',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': True,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'окръжен',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
# ...
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'признава',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'на',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'на',
#   'word[:-2]': '',
#   'word[:-1]': 'н',
#   'word[-1:]': 'а',
#   'word[-2:]': 'на',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'правото',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'собственост',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'собственост',
#   'word[:-2]': 'собствено',
#   'word[:-1]': 'собственос',
#   'word[-1:]': 'т',
#   'word[-2:]': 'ст',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'на',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'на',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'на',
#   'word[:-2]': '',
#   'word[:-1]': 'н',
#   'word[-1:]': 'а',
#   'word[-2:]': 'на',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'собственост',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'ответника',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'ответника',
#   'word[:-2]': 'ответни',
#   'word[:-1]': 'ответник',
#   'word[-1:]': 'а',
#   'word[-2:]': 'ка',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'на',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'върху',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'върху',
#   'word[:-2]': 'вър',
#   'word[:-1]': 'върх',
#   'word[-1:]': 'у',
#   'word[-2:]': 'ху',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'ответника',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'процесния',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'процесния',
#   'word[:-2]': 'процесн',
#   'word[:-1]': 'процесни',
#   'word[-1:]': 'я',
#   'word[-2:]': 'ия',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'върху',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': 'имот',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': False,
#   '+1:containsDash': False,
#   '+1:containsDot': False,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': False,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': True,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': 'имот',
#   'word[:-2]': 'им',
#   'word[:-1]': 'имо',
#   'word[-1:]': 'т',
#   'word[-2:]': 'от',
#   'ispunctuation': False,
#   'containsDash': False,
#   'containsDot': False,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': True,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': False,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'процесния',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   '+1:word.lower()': '.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:ispunctuation': True,
#   '+1:containsDash': False,
#   '+1:containsDot': True,
#   '+1:containsDigit': False,
#   '+1:singleDigit': False,
#   '+1:endsWithDot': True,
#   '+1:lonleyInitial': False,
#   '+1:singleChar': False,
#   '+1:fourDigitsYear': False,
#   '+1:gazeteerMoney': False,
#   '+1:gazeteerJudge': False,
#   '+1:gazeteerCountry': False,
#   '+1:gazeteerInstitution': False,
#   '+1:gazeteerDocRef': False,
#   '+1:gazeteerDate': False,
#   '+1:gazeteerCourt': False,
#   '+1:gazeteerLaw': False,
#   '+1:hasQuote': False},
#  {'bias': 1.0,
#   'word.lower()': '.',
#   'word[:-2]': '',
#   'word[:-1]': '',
#   'word[-1:]': '.',
#   'word[-2:]': '.',
#   'ispunctuation': True,
#   'containsDash': False,
#   'containsDot': True,
#   'containsDigit': False,
#   'lonleyInitial': False,
#   'singleChar': False,
#   'singleDigit': False,
#   'hasQuote': False,
#   'endsWithDot': True,
#   'fourDigitsYear': False,
#   'gazeteerMoney': False,
#   'gazeteerJudge': False,
#   'gazeteerCountry': False,
#   'gazeteerInstitution': False,
#   'gazeteerDocRef': False,
#   'gazeteerDate': False,
#   'gazeteerCourt': False,
#   'gazeteerLaw': False,
#   'word.isupper()': False,
#   'word.islower()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'имот',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:ispunctuation': False,
#   '-1:containsDash': False,
#   '-1:containsDot': False,
#   '-1:containsDigit': False,
#   '-1:singleDigit': False,
#   '-1:endsWithDot': False,
#   '-1:gazeteerMoney': False,
#   '-1:gazeteerJudge': False,
#   '-1:gazeteerCountry': False,
#   '-1:gazeteerInstitution': False,
#   '-1:gazeteerDocRef': False,
#   '-1:lonleyInitial': False,
#   '-1:singleChar': True,
#   '-1:fourDigitsYear': False,
#   '-1:gazeteerDate': False,
#   '-1:gazeteerCourt': False,
#   '-1:gazeteerLaw': False,
#   '-1:hasQuote': False,
#   'EOS': True}]

# %%
docs = getter.sentences
X = [sent2features(d) for d in docs]
y = [sent2labels(d) for d in docs]

# %%
from sklearn_crfsuite import CRF

crf = CRF(algorithm='lbfgs',
          c1=1.9,
          c2=0.1,
          max_iterations=100,
          all_possible_transitions=False)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn_crfsuite.metrics import flat_classification_report

# %%
pred = cross_val_predict(estimator=crf, X=X, y=y, cv=5)

# %%
report = flat_classification_report(y_pred=pred, y_true=y)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#         DATE       0.67      0.60      0.64       630
#     LOC-ADDR       0.00      0.00      0.00       229
#     LOC-CITY       0.67      0.40      0.50       207
#     LOC-CTRY       0.72      0.77      0.74        86
#      LOC-OTH       0.00      0.00      0.00        56
#       METRIC       0.00      0.00      0.00        19
#        MONEY       0.84      0.80      0.82       382
#            O       0.95      0.97      0.96     66001
#    ORG-CMPNY       0.61      0.42      0.50       340
#    ORG-COURT       0.77      0.79      0.78       987
#     ORG-INST       0.50      0.04      0.07        26
#      PER-JDG       0.00      0.00      0.00        12
#      PER-LWR       0.00      0.00      0.00        18
#      PER-OTH       0.67      0.55      0.60       756
# PER-PLANTIFF       0.00      0.00      0.00        23
#      REF-DOC       0.74      0.55      0.63      1273
#      REF-LAW       0.71      0.62      0.66      3108
#         TIME       0.00      0.00      0.00        10
#
#     accuracy                           0.93     74163
#    macro avg       0.44      0.36      0.38     74163
# weighted avg       0.92      0.93      0.92     74163

# %%
crf.fit(X, y)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=1.9, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
test_text = "В обжалваното в настоящото производство въззивно решение съдът се е произнесъл по сходен казус. Уговорената в предварителния договор продажна цена на имота е 8 000лв., от които при подписването му са заплатени 500лв., а остатъкът е следвало да бъде заплатен „при оформяне на продажбата в нотариална форма, но не по-късно от 28.02.05г.”. При това продавачката е поела задължението да прехвърли собствеността в нотариална форма след като и бъде предложен остатъкът от цената „не по-късно от 28.02.05г.”. Уговорено е също, че ако купувачът не изпълни паричното си задължение от 7500лв. в уговорения срок, той губи правото да иска връщане на платените от него 500лв. / чл.VІ от договора/, а ако продавачката откаже да изпълни задължението си за оформяне на продажбата по нотариален ред, тя дължи на купувача 1000лв., представляващи получената сума по този договор и обезщетение за неизпълнение на това задължение, като купувачът има право да иска обявяване на договора за окончателен по реда на чл.19, ал.3 от ЗЗД /чл.VІІ от договора/."

# %%
test_text_features = sent2features([(t, None) for t in twt().tokenize(test_text)])
res = crf.predict([test_text_features])

# %%
list(zip(twt().tokenize(test_text), res[0]))
# Out:
# [('В', 'O'),
#  ('обжалваното', 'O'),
#  ('в', 'O'),
#  ('настоящото', 'O'),
#  ('производство', 'O'),
#  ('въззивно', 'O'),
#  ('решение', 'O'),
#  ('съдът', 'O'),
#  ('се', 'O'),
#  ('е', 'O'),
#  ('произнесъл', 'O'),
#  ('по', 'O'),
#  ('сходен', 'O'),
#  ('казус.', 'O'),
#  ('Уговорената', 'O'),
#  ('в', 'O'),
#  ('предварителния', 'O'),
#  ('договор', 'O'),
#  ('продажна', 'O'),
#  ('цена', 'O'),
#  ('на', 'O'),
#  ('имота', 'O'),
#  ('е', 'O'),
#  ('8', 'O'),
#  ('000лв.', 'O'),
#  (',', 'O'),
#  ('от', 'O'),
#  ('които', 'O'),
#  ('при', 'O'),
#  ('подписването', 'O'),
#  ('му', 'O'),
#  ('са', 'O'),
#  ('заплатени', 'O'),
#  ('500лв.', 'O'),
#  (',', 'O'),
#  ('а', 'O'),
#  ('остатъкът', 'O'),
#  ('е', 'O'),
#  ('следвало', 'O'),
#  ('да', 'O'),
#  ('бъде', 'O'),
#  ('заплатен', 'O'),
#  ('„', 'O'),
#  ('при', 'O'),
#  ('оформяне', 'O'),
#  ('на', 'O'),
#  ('продажбата', 'O'),
#  ('в', 'O'),
#  ('нотариална', 'O'),
#  ('форма', 'O'),
#  (',', 'O'),
#  ('но', 'O'),
#  ('не', 'O'),
#  ('по-късно', 'O'),
#  ('от', 'O'),
#  ('28.02.05г.', 'O'),
#  ('”', 'O'),
#  ('.', 'O'),
#  ('При', 'O'),
#  ('това', 'O'),
#  ('продавачката', 'O'),
#  ('е', 'O'),
#  ('поела', 'O'),
#  ('задължението', 'O'),
#  ('да', 'O'),
#  ('прехвърли', 'O'),
#  ('собствеността', 'O'),
#  ('в', 'O'),
#  ('нотариална', 'O'),
#  ('форма', 'O'),
#  ('след', 'O'),
#  ('като', 'O'),
#  ('и', 'O'),
#  ('бъде', 'O'),
#  ('предложен', 'O'),
#  ('остатъкът', 'O'),
#  ('от', 'O'),
#  ('цената', 'O'),
#  ('„', 'O'),
#  ('не', 'O'),
#  ('по-късно', 'O'),
#  ('от', 'O'),
#  ('28.02.05г.', 'O'),
#  ('”', 'O'),
#  ('.', 'O'),
#  ('Уговорено', 'O'),
#  ('е', 'O'),
#  ('също', 'O'),
#  (',', 'O'),
#  ('че', 'O'),
#  ('ако', 'O'),
#  ('купувачът', 'O'),
#  ('не', 'O'),
#  ('изпълни', 'O'),
#  ('паричното', 'O'),
#  ('си', 'O'),
#  ('задължение', 'O'),
#  ('от', 'O'),
#  ('7500лв.', 'O'),
#  ('в', 'O'),
#  ('уговорения', 'O'),
#  ('срок', 'O'),
#  (',', 'O'),
#  ('той', 'O'),
#  ('губи', 'O'),
#  ('правото', 'O'),
#  ('да', 'O'),
#  ('иска', 'O'),
#  ('връщане', 'O'),
#  ('на', 'O'),
#  ('платените', 'O'),
#  ('от', 'O'),
#  ('него', 'O'),
#  ('500лв.', 'O'),
#  ('/', 'O'),
#  ('чл.VІ', 'O'),
#  ('от', 'O'),
#  ('договора/', 'O'),
#  (',', 'O'),
#  ('а', 'O'),
#  ('ако', 'O'),
#  ('продавачката', 'O'),
#  ('откаже', 'O'),
#  ('да', 'O'),
#  ('изпълни', 'O'),
#  ('задължението', 'O'),
#  ('си', 'O'),
#  ('за', 'O'),
#  ('оформяне', 'O'),
#  ('на', 'O'),
#  ('продажбата', 'O'),
#  ('по', 'O'),
#  ('нотариален', 'O'),
#  ('ред', 'O'),
#  (',', 'O'),
#  ('тя', 'O'),
#  ('дължи', 'O'),
#  ('на', 'O'),
#  ('купувача', 'O'),
#  ('1000лв.', 'O'),
#  (',', 'O'),
#  ('представляващи', 'O'),
#  ('получената', 'O'),
#  ('сума', 'O'),
#  ('по', 'O'),
#  ('този', 'O'),
#  ('договор', 'O'),
#  ('и', 'O'),
#  ('обезщетение', 'O'),
#  ('за', 'O'),
#  ('неизпълнение', 'O'),
#  ('на', 'O'),
#  ('това', 'O'),
#  ('задължение', 'O'),
#  (',', 'O'),
#  ('като', 'O'),
#  ('купувачът', 'O'),
#  ('има', 'O'),
#  ('право', 'O'),
#  ('да', 'O'),
#  ('иска', 'O'),
#  ('обявяване', 'O'),
#  ('на', 'O'),
#  ('договора', 'O'),
#  ('за', 'O'),
#  ('окончателен', 'O'),
#  ('по', 'O'),
#  ('реда', 'O'),
#  ('на', 'O'),
#  ('чл.19', 'REF-LAW'),
#  (',', 'REF-LAW'),
#  ('ал.3', 'REF-LAW'),
#  ('от', 'REF-LAW'),
#  ('ЗЗД', 'REF-LAW'),
#  ('/чл.VІІ', 'O'),
#  ('от', 'O'),
#  ('договора/', 'O'),
#  ('.', 'O')]

# %%
# unannotated_data = []

# with jsonlines.open('test-annotate.jsonl') as reader:
#     for obj in reader:
#         unannotated_data.append(obj)

# %%
# import csv
# with open('predicted_annotations.csv', mode='w', encoding='utf-8') as results_file:
#     employee_writer = csv.writer(results_file, delimiter='\t', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#     for k, doc in enumerate(unannotated_data):
#         if k == 500:
#             break
#         text = doc['text']
#         ann_text_features = sent2features([(t, None) for t in twt().tokenize(text)])
#         res = crf.predict([ann_text_features])

#         for token in list(zip(twt().tokenize(text), res[0])):
#             if token[1] != 'O':
#                 employee_writer.writerow([token[0], token[1]])
#             else:
#                 employee_writer.writerow([token[0], ""])
#         employee_writer.writerow([])

# %%
import pickle

pickle.dump( crf, open( "crf_model-with-reg.pkl", "wb" ) )

# %%
import eli5
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>DATE</th>
#
#                 <th>LOC-ADDR</th>
#
#                 <th>LOC-CITY</th>
#
#                 <th>LOC-CTRY</th>
#
#                 <th>LOC-OTH</th>
#
#                 <th>METRIC</th>
#
#                 <th>MONEY</th>
#
#                 <th>O</th>
#
#                 <th>ORG-CMPNY</th>
#
#                 <th>ORG-COURT</th>
#
#                 <th>ORG-INST</th>
#
#                 <th>PER-JDG</th>
#
#                 <th>PER-LWR</th>
#
#                 <th>PER-OTH</th>
#
#                 <th>PER-PLANTIFF</th>
#
#                 <th>REF-DOC</th>
#
#                 <th>REF-LAW</th>
#
#                 <th>TIME</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>DATE</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="DATE &rArr; DATE">
#                             5.949
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; LOC-ADDR">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; LOC-CITY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; LOC-CTRY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; LOC-OTH">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; METRIC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; MONEY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.85%)" title="DATE &rArr; O">
#                             -0.101
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; ORG-CMPNY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; ORG-COURT">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; ORG-INST">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; PER-JDG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; PER-LWR">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; PER-OTH">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; PER-PLANTIFF">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; REF-DOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; REF-LAW">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>LOC-ADDR</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.80%)" title="LOC-ADDR &rArr; LOC-ADDR">
#                             5.2
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; LOC-CITY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; LOC-CTRY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; LOC-OTH">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; METRIC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; MONEY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.92%)" title="LOC-ADDR &rArr; O">
#                             -1.349
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; ORG-CMPNY">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; ORG-COURT">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; ORG-INST">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; PER-JDG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; PER-LWR">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; PER-OTH">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; PER-PLANTIFF">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-ADDR &rArr; REF-DOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="LOC-A
